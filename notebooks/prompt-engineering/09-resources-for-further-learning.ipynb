# %% [markdown]
# # Resources for Further Learning
#
# Source slide: `slides/prompt-engineering/09_Resources_for_Further_Learning.md`
#
# This source slide is a reference module, so the notebook stays intentionally brief.
#
# No standalone prompt technique examples are included here. Use this module as a reading list for improving the technique notebooks and your own prompt experiments.
