# %% [markdown]
# # Resources for Further Learning
#
# Source slide: `slides/prompt-engineering/09_Resources_for_Further_Learning.md`
#
# This slide is a reading list rather than a technique list, so the notebook stays brief.

# %% [markdown]
# No technique examples are added here because the source slide is a reference list, not a technique slide.
