# %% [markdown]
# # Introduction to Prompt Engineering
#
# Source slide: `slides/prompt-engineering/01_Introduction_to_Prompt_Engineering.md`
#
# This source slide is an overview module, so the notebook stays intentionally brief.
#
# No standalone prompt technique examples are included in this module. Use it as orientation for the technique notebooks that follow.
