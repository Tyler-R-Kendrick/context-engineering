# %% [markdown]
# # Introduction to Prompt Engineering
#
# Source slide: `slides/prompt-engineering/01_Introduction_to_Prompt_Engineering.md`
#
# This slide is orientation content rather than a list of techniques, so the notebook stays brief.

# %% [markdown]
# No technique examples are added here because the source slide does not name any prompt-engineering techniques.
